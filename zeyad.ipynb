# %%
#connect with vncviewer or other vnc software
#dont forget to add your ngrok authtoken
#vnc passsword is lollipop

# %%
# !apt update && apt install expect xvfb tightvncserver -y && dpkg --configure -a

# %%
# !apt install lxde -y

# %%
# !wget https://raw.githubusercontent.com/NotRealZeyad/RD/main/wmaker.sh && wget https://raw.githubusercontent.com/TaheemReal/YOUTUBE-FILES/main/KAGGLE_RDP/vnc.sh

# %%
# !export USER=root && expect vnc.sh

# %%
# !wget https://bin.equinox.io/c/bNyj1mQVY4c/ngrok-v3-stable-linux-amd64.tgz && tar xf ngrok-v3-stable-linux-amd64.tgz && rm -r ngrok-v3-stable-linux-amd64.tgz

# %%
# !./ngrok authtoken "your ngrok authtoken here"

# %%
# !bash wmaker.sh
